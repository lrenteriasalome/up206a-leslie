# %%
import geopandas as gpd

# %% [markdown]
# I set my data frames to gpd in order to get the best data visualizaiton.

# %%
Housing = gpd.read_file('H_acs2019_5yr_B25024_14000US06037222001.geojson')

# %% [markdown]
# My data imported succesfully. You will see many runs, since I had to play with multiple sets and ran the entire data.

# %%
Race = gpd.read_file('R_acs2019_5yr_B03002_14000US06037222001.geojson')

# %% [markdown]
# My intention is to merge both files in order to map out single family homes and race/ethnicity.

# %%
Housing.head()
# Out:
#                 geoid                                   name    B25024001  \
# 0             01000US                          United States  137428986.0
# 1           04000US06                             California   14175976.0
# 2        05000US06037                 Los Angeles County, CA    3542800.0
# 3  14000US06037101110  Census Tract 1011.10, Los Angeles, CA       1749.0
# 4  14000US06037101122  Census Tract 1011.22, Los Angeles, CA       1396.0
#
#    B25024001, Error   B25024002  B25024002, Error  B25024003  \
# 0            6044.0  84644765.0          116530.0  8048562.0
# 1            1184.0   8185405.0           11488.0   998444.0
# 2            1023.0   1722121.0            4802.0   223134.0
# 3              47.0      1156.0             108.0       53.0
# 4              15.0      1396.0              15.0        0.0
#
#    B25024003, Error  B25024004  B25024004, Error  B25024005  B25024005, Error  \
# ...

# %% [markdown]
# I was able to see the datas first 5 rows to make sure it looked right.

# %%
Race.head()
# Out:
#                 geoid                                   name    B03002001  \
# 0             01000US                          United States  324697795.0
# 1           04000US06                             California   39283497.0
# 2        05000US06037                 Los Angeles County, CA   10081570.0
# 3  14000US06037101110  Census Tract 1011.10, Los Angeles, CA       4283.0
# 4  14000US06037101122  Census Tract 1011.22, Los Angeles, CA       3405.0
#
#    B03002001, Error    B03002002  B03002002, Error    B03002003  \
# 0               0.0  266218425.0            2120.0  197100373.0
# 1               0.0   23955809.0               0.0   14605312.0
# 2               0.0    5193136.0               0.0    2641770.0
# 3             443.0       3095.0             354.0       2616.0
# 4             334.0       3258.0             344.0       2882.0
#
#    B03002003, Error   B03002004  B03002004, Error  B03002005  \
# 0            9392.0  39977554.0           39872.0  2160378.0
# ...

# %% [markdown]
# I was able to see the datas first 5 rows to make sure it looked right.

# %%
Housing.shape
# Out:
# (2349, 25)

# %%
Race.shape
# Out:
# (2349, 45)

# %%
Housing.plot(figsize=(12,12))
# Out:
# <AxesSubplot:>

# %% [markdown]
# I realized that my data set had a row with U.S number total and made my plt look weird.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
Housing.sample()
# Out:
#                    geoid                                   name  B25024001  \
# 2245  14000US06037910714  Census Tract 9107.14, Los Angeles, CA      930.0
#
#       B25024001, Error  B25024002  B25024002, Error  B25024003  \
# 2245              23.0      915.0              28.0       15.0
#
#       B25024003, Error  B25024004  B25024004, Error  B25024005  \
# 2245              16.0        0.0              12.0        0.0
#
#       B25024005, Error  B25024006  B25024006, Error  B25024007  \
# 2245              12.0        0.0              12.0        0.0
#
#       B25024007, Error  B25024008  B25024008, Error  B25024009  \
# 2245              12.0        0.0              12.0        0.0
#
#       B25024009, Error  B25024010  B25024010, Error  B25024011  \
# 2245              12.0        0.0              12.0        0.0
#
#       B25024011, Error                                           geometry
# 2245              12.0  MULTIPOLYGON (((-118.04520 34.55846, -118.0451...

# %%
Housing.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             2349 non-null   object
#  1   name              2349 non-null   object
#  2   B25024001         2349 non-null   float64
#  3   B25024001, Error  2349 non-null   float64
#  4   B25024002         2349 non-null   float64
#  5   B25024002, Error  2349 non-null   float64
#  6   B25024003         2349 non-null   float64
#  7   B25024003, Error  2349 non-null   float64
#  8   B25024004         2349 non-null   float64
#  9   B25024004, Error  2349 non-null   float64
#  10  B25024005         2349 non-null   float64
#  11  B25024005, Error  2349 non-null   float64
#  12  B25024006         2349 non-null   float64
#  13  B25024006, Error  2349 non-null   float64
#  14  B25024007         2349 non-null   float64
#  15  B25024007, Error  2349 non-null   float64
# ...

# %%
Housing.geoid.head()
# Out:
# 0               01000US
# 1             04000US06
# 2          05000US06037
# 3    14000US06037101110
# 4    14000US06037101122
# Name: geoid, dtype: object

# %%
Housing.head()
# Out:
#                 geoid                                   name    B25024001  \
# 0             01000US                          United States  137428986.0
# 1           04000US06                             California   14175976.0
# 2        05000US06037                 Los Angeles County, CA    3542800.0
# 3  14000US06037101110  Census Tract 1011.10, Los Angeles, CA       1749.0
# 4  14000US06037101122  Census Tract 1011.22, Los Angeles, CA       1396.0
#
#    B25024001, Error   B25024002  B25024002, Error  B25024003  \
# 0            6044.0  84644765.0          116530.0  8048562.0
# 1            1184.0   8185405.0           11488.0   998444.0
# 2            1023.0   1722121.0            4802.0   223134.0
# 3              47.0      1156.0             108.0       53.0
# 4              15.0      1396.0              15.0        0.0
#
#    B25024003, Error  B25024004  B25024004, Error  B25024005  B25024005, Error  \
# ...

# %% [markdown]
# I ran head and info to get a braoder perspective of my data. Now, Iwill delete the U.S, California and county rows.

# %%
Housing = Housing.drop([2])

# %%
Housing.head()
# Out:
#                 geoid                                   name    B25024001  \
# 0             01000US                          United States  137428986.0
# 1           04000US06                             California   14175976.0
# 3  14000US06037101110  Census Tract 1011.10, Los Angeles, CA       1749.0
# 4  14000US06037101122  Census Tract 1011.22, Los Angeles, CA       1396.0
# 5  14000US06037101210  Census Tract 1012.10, Los Angeles, CA       2392.0
#
#    B25024001, Error   B25024002  B25024002, Error  B25024003  \
# 0            6044.0  84644765.0          116530.0  8048562.0
# 1            1184.0   8185405.0           11488.0   998444.0
# 3              47.0      1156.0             108.0       53.0
# 4              15.0      1396.0              15.0        0.0
# 5              74.0       318.0             110.0      160.0
#
#    B25024003, Error  B25024004  B25024004, Error  B25024005  B25024005, Error  \
# ...

# %%
Housing = Housing.drop([1])

# %%
Housing.head()
# Out:
#                 geoid                                   name    B25024001  \
# 0             01000US                          United States  137428986.0
# 3  14000US06037101110  Census Tract 1011.10, Los Angeles, CA       1749.0
# 4  14000US06037101122  Census Tract 1011.22, Los Angeles, CA       1396.0
# 5  14000US06037101210  Census Tract 1012.10, Los Angeles, CA       2392.0
# 6  14000US06037101220  Census Tract 1012.20, Los Angeles, CA       1384.0
#
#    B25024001, Error   B25024002  B25024002, Error  B25024003  \
# 0            6044.0  84644765.0          116530.0  8048562.0
# 3              47.0      1156.0             108.0       53.0
# 4              15.0      1396.0              15.0        0.0
# 5              74.0       318.0             110.0      160.0
# 6              45.0       717.0              96.0       96.0
#
#    B25024003, Error  B25024004  B25024004, Error  B25024005  B25024005, Error  \
# ...

# %%
Housing = Housing.drop([0])

# %%
Housing.head()
# Out:
#                 geoid                                   name  B25024001  \
# 3  14000US06037101110  Census Tract 1011.10, Los Angeles, CA     1749.0
# 4  14000US06037101122  Census Tract 1011.22, Los Angeles, CA     1396.0
# 5  14000US06037101210  Census Tract 1012.10, Los Angeles, CA     2392.0
# 6  14000US06037101220  Census Tract 1012.20, Los Angeles, CA     1384.0
# 7  14000US06037101300     Census Tract 1013, Los Angeles, CA     1601.0
#
#    B25024001, Error  B25024002  B25024002, Error  B25024003  B25024003, Error  \
# 3              47.0     1156.0             108.0       53.0              33.0
# 4              15.0     1396.0              15.0        0.0              12.0
# 5              74.0      318.0             110.0      160.0              81.0
# 6              45.0      717.0              96.0       96.0              44.0
# 7              52.0     1481.0              69.0       94.0              53.0
#
# ...

# %% [markdown]
# Now that I set my data scope to LA county  I will list out my data set and remove any comuns that I do not need.

# %%
list(Housing)
# Out:
# ['geoid',
#  'name',
#  'B25024001',
#  'B25024001, Error',
#  'B25024002',
#  'B25024002, Error',
#  'B25024003',
#  'B25024003, Error',
#  'B25024004',
#  'B25024004, Error',
#  'B25024005',
#  'B25024005, Error',
#  'B25024006',
#  'B25024006, Error',
#  'B25024007',
#  'B25024007, Error',
#  'B25024008',
#  'B25024008, Error',
#  'B25024009',
#  'B25024009, Error',
#  'B25024010',
#  'B25024010, Error',
#  'B25024011',
#  'B25024011, Error',
#  'geometry']

# %%
columns_to_keep = ['geoid',
 'name',
 'B25024001',
 'B25024002',
 'B25024003',
 'geometry']

# %% [markdown]
# I decided to keeo the single family occupancy columns that will shorter my datat and give my a focus on where in LA are single unit homes.

# %%
Housing = Housing[columns_to_keep]

# %%
Housing.head()
# Out:
#                 geoid                                   name  B25024001  \
# 3  14000US06037101110  Census Tract 1011.10, Los Angeles, CA     1749.0
# 4  14000US06037101122  Census Tract 1011.22, Los Angeles, CA     1396.0
# 5  14000US06037101210  Census Tract 1012.10, Los Angeles, CA     2392.0
# 6  14000US06037101220  Census Tract 1012.20, Los Angeles, CA     1384.0
# 7  14000US06037101300     Census Tract 1013, Los Angeles, CA     1601.0
#
#    B25024002  B25024003                                           geometry
# 3     1156.0       53.0  MULTIPOLYGON (((-118.30229 34.25870, -118.3009...
# 4     1396.0        0.0  MULTIPOLYGON (((-118.30334 34.27371, -118.3033...
# 5      318.0      160.0  MULTIPOLYGON (((-118.29945 34.25598, -118.2979...
# 6      717.0       96.0  MULTIPOLYGON (((-118.28593 34.25227, -118.2859...
# 7     1481.0       94.0  MULTIPOLYGON (((-118.27822 34.25068, -118.2782...

# %%
list(Housing)
# Out:
# ['geoid', 'name', 'B25024001', 'B25024002', 'B25024003', 'geometry']

# %%
Housing.columns = ['geoid',
 'name',
 'Total',
 '1, detached',
 '1, attached',
 'geometry']

# %% [markdown]
# I renamed my columns to the two data sets Iwill be using.

# %%
Housing.head()
# Out:
#                 geoid                                   name   Total  \
# 3  14000US06037101110  Census Tract 1011.10, Los Angeles, CA  1749.0
# 4  14000US06037101122  Census Tract 1011.22, Los Angeles, CA  1396.0
# 5  14000US06037101210  Census Tract 1012.10, Los Angeles, CA  2392.0
# 6  14000US06037101220  Census Tract 1012.20, Los Angeles, CA  1384.0
# 7  14000US06037101300     Census Tract 1013, Los Angeles, CA  1601.0
#
#    1, detached  1, attached                                           geometry
# 3       1156.0         53.0  MULTIPOLYGON (((-118.30229 34.25870, -118.3009...
# 4       1396.0          0.0  MULTIPOLYGON (((-118.30334 34.27371, -118.3033...
# 5        318.0        160.0  MULTIPOLYGON (((-118.29945 34.25598, -118.2979...
# 6        717.0         96.0  MULTIPOLYGON (((-118.28593 34.25227, -118.2859...
# 7       1481.0         94.0  MULTIPOLYGON (((-118.27822 34.25068, -118.2782...

# %%
random_tract = Housing.sample()
random_tract
# Out:
#                   geoid                                   name   Total  \
# 975  14000US06037296402  Census Tract 2964.02, Los Angeles, CA  1213.0
#
#      1, detached  1, attached  \
# 975       1081.0         27.0
#
#                                               geometry
# 975  MULTIPOLYGON (((-118.30969 33.74337, -118.3096...

# %%
random_tract.plot()
# Out:
# <AxesSubplot:>

# %%
Housing['Total'].head()
# Out:
# 3    1749.0
# 4    1396.0
# 5    2392.0
# 6    1384.0
# 7    1601.0
# Name: Total, dtype: float64

# %%
random_tract.iloc[0]['Total']
# Out:
# 1213.0

# %%
print('Single Unit ' + str(random_tract.iloc[0]['Total']))
# Out:
# Single Unit 1213.0

# %%
Housing['Total'].describe()
# Out:
# count    2346.000000
# mean     1510.144928
# std       675.999311
# min         0.000000
# 25%      1076.000000
# 50%      1412.000000
# 75%      1859.750000
# max      6158.000000
# Name: Total, dtype: float64

# %%
Housing['Total'].plot.hist(figsize=(15,8),bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Housing['1, attached'].describe()
# Out:
# count    2346.000000
# mean       95.112532
# std       105.851508
# min         0.000000
# 25%        23.000000
# 50%        64.000000
# 75%       132.750000
# max      1296.000000
# Name: 1, attached, dtype: float64

# %%
Housing_sorted = Housing.sort_values(by='Total',ascending = False)

# %%
Housing_sorted[['name','Total']].head(10)
# Out:
#                                        name   Total
# 2149  Census Tract 7029.01, Los Angeles, CA  6158.0
# 925   Census Tract 2756.02, Los Angeles, CA  6148.0
# 549      Census Tract 2079, Los Angeles, CA  4902.0
# 2109     Census Tract 7002, Los Angeles, CA  4568.0
# 2126  Census Tract 7014.02, Los Angeles, CA  4543.0
# 2110     Census Tract 7003, Los Angeles, CA  4300.0
# 543   Census Tract 2073.01, Los Angeles, CA  4150.0
# 2200  Census Tract 9010.04, Los Angeles, CA  4088.0
# 548   Census Tract 2077.10, Los Angeles, CA  4051.0
# 2137  Census Tract 7021.02, Los Angeles, CA  3991.0

# %% [markdown]
# Census tracts that have the most single unit structure housing.

# %%
Housing_sorted.head(10).plot(figsize=(12,12))
# Out:
# <AxesSubplot:>

# %%
Housing_sorted.head(10).plot(figsize=(10,10),
                          column='Total',
                          legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# What are the census tract that have with most single family homes?

# %%
Housing[Housing['Total']==0]
# Out:
#                    geoid                                   name  Total  \
# 850   14000US06037265301  Census Tract 2653.01, Los Angeles, CA    0.0
# 1057  14000US06037320000     Census Tract 3200, Los Angeles, CA    0.0
# 1125  14000US06037403200     Census Tract 4032, Los Angeles, CA    0.0
# 1749  14000US06037551600     Census Tract 5516, Los Angeles, CA    0.0
# 1892  14000US06037574601  Census Tract 5746.01, Los Angeles, CA    0.0
# 1894  14000US06037574700     Census Tract 5747, Los Angeles, CA    0.0
# 2199  14000US06037901003  Census Tract 9010.03, Los Angeles, CA    0.0
# 2300  14000US06037920200     Census Tract 9202, Los Angeles, CA    0.0
# 2320  14000US06037980001  Census Tract 9800.01, Los Angeles, CA    0.0
# 2321  14000US06037980002  Census Tract 9800.02, Los Angeles, CA    0.0
# 2322  14000US06037980003  Census Tract 9800.03, Los Angeles, CA    0.0
# 2323  14000US06037980004  Census Tract 9800.04, Los Angeles, CA    0.0
# ...

# %% [markdown]
# Census tracts that do not have single unit housing

# %%
Housing_no_single = Housing[Housing['Total']==0]

# %%
print('There are ' + str(len(Housing_no_single)) + ' census tracts with no single unit housing')
# Out:
# There are 26 census tracts with no single unit housing

# %%
Housing_no_single[['name','Total']]
# Out:
#                                        name  Total
# 850   Census Tract 2653.01, Los Angeles, CA    0.0
# 1057     Census Tract 3200, Los Angeles, CA    0.0
# 1125     Census Tract 4032, Los Angeles, CA    0.0
# 1749     Census Tract 5516, Los Angeles, CA    0.0
# 1892  Census Tract 5746.01, Los Angeles, CA    0.0
# 1894     Census Tract 5747, Los Angeles, CA    0.0
# 2199  Census Tract 9010.03, Los Angeles, CA    0.0
# 2300     Census Tract 9202, Los Angeles, CA    0.0
# 2320  Census Tract 9800.01, Los Angeles, CA    0.0
# 2321  Census Tract 9800.02, Los Angeles, CA    0.0
# 2322  Census Tract 9800.03, Los Angeles, CA    0.0
# 2323  Census Tract 9800.04, Los Angeles, CA    0.0
# 2324  Census Tract 9800.05, Los Angeles, CA    0.0
# 2325  Census Tract 9800.06, Los Angeles, CA    0.0
# 2326  Census Tract 9800.07, Los Angeles, CA    0.0
# 2330  Census Tract 9800.13, Los Angeles, CA    0.0
# 2333  Census Tract 9800.18, Los Angeles, CA    0.0
# ...

# %%
list(Housing)
# Out:
# ['geoid', 'name', 'Total', '1, detached', '1, attached', 'geometry']

# %%
Housing['Percent Single Family Home '] = Housing['1, detached']/Housing['Total']*100
Housing['Percent Townhome etc'] = Housing['1, attached']/Housing['Total']*100

# %%
Housing.sample(5)
# Out:
#                    geoid                                   name   Total  \
# 1205  14000US06037406602  Census Tract 4066.02, Los Angeles, CA  1276.0
# 596   14000US06037211910  Census Tract 2119.10, Los Angeles, CA  1971.0
# 1497  14000US06037502901  Census Tract 5029.01, Los Angeles, CA  1444.0
# 396   14000US06037187300     Census Tract 1873, Los Angeles, CA  1626.0
# 340   14000US06037141400     Census Tract 1414, Los Angeles, CA  2132.0
#
#       1, detached  1, attached  \
# 1205       1130.0         59.0
# 596          10.0          0.0
# 1497       1335.0         73.0
# 396         817.0        158.0
# 340        1080.0          9.0
#
#                                                geometry  \
# 1205  MULTIPOLYGON (((-117.94385 34.05057, -117.9437...
# 596   MULTIPOLYGON (((-118.30036 34.06720, -118.3003...
# 1497  MULTIPOLYGON (((-118.04650 33.94143, -118.0464...
# 396   MULTIPOLYGON (((-118.26544 34.11216, -118.2654...
# ...

# %%
Housing.plot(figsize=(12,12),
                 column='1, detached',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot:>

# %%
# equal interval
Housing.plot(figsize=(12,12),
                 column='1, detached',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot:>

# %%
Housing.plot(figsize=(12,12),
                 column='1, detached',
                 legend=True, 
                 scheme='quantiles')
# Out:
# <AxesSubplot:>

# %%
Housing.plot(figsize=(12,12),
                 column='1, detached',
                 legend=True, 
                 scheme='quantiles',
                 cmap='YlOrRd'
        )
# Out:
# <AxesSubplot:>

# %%
Housing.plot(figsize=(12,12),
            column='1, detached', 
            cmap='YlGn', 
            scheme='user_defined', # to use custom breaks
            classification_kwds={'bins':[20,40,60,80,100]}, # define the breaks here
            edgecolor='white', 
            linewidth=0.1, 
            legend=True
           )
# Out:
# <AxesSubplot:>

# %%
# set sharex and sharey to true to scale each map equally
fig, axs = plt.subplots(1, 2, figsize=(15, 12), sharex=True, sharey=True)

# name each subplot
ax1, ax2 = axs

# percent hispanic map on the left
Housing.plot(column='1, detached', 
            cmap='YlGn', 
            scheme='user_defined',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0.1, 
            ax=ax1, # this assigns the map to the subplot,
            legend=True
           )

ax1.axis("off")
ax1.set_title("Percent with Single Family Homes")


# percent black map on the right
Housing.plot(column='1, attached', 
            cmap='BuGn', 
            scheme='user_defined',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0.1, 
            ax=ax2, # this assigns the map to the subplot
            legend=True
           )

ax2.axis("off")
ax2.set_title("Percent with Townhomes etc")
# Out:
# Text(0.5, 1.0, 'Percent with Townhomes etc')

# %%
Housing[Housing['1, detached'] > 80]
# Out:
#                    geoid                                   name   Total  \
# 3     14000US06037101110  Census Tract 1011.10, Los Angeles, CA  1749.0
# 4     14000US06037101122  Census Tract 1011.22, Los Angeles, CA  1396.0
# 5     14000US06037101210  Census Tract 1012.10, Los Angeles, CA  2392.0
# 6     14000US06037101220  Census Tract 1012.20, Los Angeles, CA  1384.0
# 7     14000US06037101300     Census Tract 1013, Los Angeles, CA  1601.0
# 8     14000US06037101400     Census Tract 1014, Los Angeles, CA  1584.0
# 9     14000US06037102103  Census Tract 1021.03, Los Angeles, CA   742.0
# 10    14000US06037102104  Census Tract 1021.04, Los Angeles, CA  1343.0
# 11    14000US06037102105  Census Tract 1021.05, Los Angeles, CA   584.0
# 12    14000US06037102107  Census Tract 1021.07, Los Angeles, CA  1379.0
# 13    14000US06037103101  Census Tract 1031.01, Los Angeles, CA   984.0
# 14    14000US06037103102  Census Tract 1031.02, Los Angeles, CA  1736.0
# ...

# %% [markdown]
# The data above listed the densus tracts with over 90 percent single family homes. It is not surprising to see that many. Now I will see the amount of homes over 80 percent.

# %%
Housing[Housing['1, detached'] > 80].plot(figsize=(12,10),color="Red")
# Out:
# <AxesSubplot:>

# %%
Housing_web_mercator = Housing.to_crs(epsg=3857)

# %%
# use subplots that make it easier to create multiple layered maps
fig, ax = plt.subplots(figsize=(15, 15))

# add the layer with ax=ax in the argument 
# alpha is the opacity
Housing_web_mercator[Housing_web_mercator['1, detached'] > 80].plot(
                                                               ax=ax, 
                                                               color="blue",
                                                               alpha=0.4
)

# turn the axis off
ax.axis('off')

# set a title
ax.set_title('Census Tracts with more than 80% Single Family Homes',fontsize=24,pad=20)

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Voyager)

# %% [markdown]
# My map showed the census tracts with single family homes. I am going to try and zoom in and see of there is a larger difference between single family homes and town/condo homes.

# %%
# create the 1x2 subplots
fig, axs = plt.subplots(1, 2, figsize=(15, 12),sharex=True,sharey=True)

# name each subplot
ax1, ax2 = axs

# add the layer with ax=ax in the argument 
Housing_web_mercator[Housing_web_mercator['1, detached'] > 80].plot(ax=ax1, 
                                                                           alpha=0.4, 
                                                                           color="blue")

ax1.axis("off")
ax1.set_title('Census Tracts with more than 50% Single Family Homes',fontsize=14, pad=20)

# add a basemap
ctx.add_basemap(ax1) # default zoom

# add the layer with ax=ax in the argument 
Housing_web_mercator[Housing_web_mercator['1, attached'] > 50].plot(ax=ax2, 
                                                                           alpha=0.3, 
                                                                           color="red")


ax2.axis("off")
ax2.set_title('Census Tracts with more than 50% town homes',fontsize=14, pad=20)
# add a basemap
ctx.add_basemap(ax2, zoom=9) # zoom override

# %%
plt.savefig("map.png")
